# %% [markdown]
# # Exploratory Data Analysis
#
#
#
# load a CSV dataset from a local file using `pandas.read_csv,,,
# use basic Pandas functions for Exploratory Data Analysis-EDA
# describe and discriminate between basic data types such as categorical, quantitative, continuous, discrete, ordinal, nominal and identifier

# %% [markdown]
# # [Objective 01] LOAD THE DATASET AND EXPLORE

# %% [markdown]
# ## Overview
#
#
#
# Steps for loading a dataset:
#
# 1) Learn as much as you can about the dataset:
#  - Number of rows
#  - Number of columns
#  - Column headers (Is there a "data dictionary"?)
#  - Is there missing data?
#  - Open the raw file and look at it - it may not be formatted the way you expect.
#
# 2) Try loading the dataset using `pandas.read_csv()` and if things aren't acting the way that you expect, investigate until you can get it loading correctly.
#
# 3) Keep in mind that functions like `pandas.read_csv()` have a lot of optional parameters that might help us change the way that data is read in. If you get stuck, google, read the documentation, and try things out.
#
# 4) You might need to type out column headers by hand if they are not provided in a neat format in the original dataset. It can be a drag.

# %% [markdown]
# ## Follow Along

# %% [markdown]
# ### Learn about the dataset and look at the raw file.

# %%
# Learn about the dataset and look at the raw file
file_path = 'iris_dirty (1).csv'

import pandas as pd
df = pd.read_csv(file_path)

# %% [markdown]
# ### Attempt to load it.

# %%
#Print the first 5 rows:
print(df.head())
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa

# %%
#Print the last 5 rows:
print(df.tail())
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 145         146           6.7          3.0           5.2          2.3
# 146         147           6.3          2.5           5.0          1.9
# 147         148           6.5          3.0           5.2          2.0
# 148         149           6.2          3.4           5.4          2.3
# 149         150           NaN          3.0           5.1          1.8
#
#        Species
# 145  virginica
# 146  virginica
# 147  virginica
# 148  virginica
# 149  virginica

# %%
#Can you print the first 7 rows?
print(df.head(7))
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa
# 5           6           5.4          NaN           1.7          0.4  setosa
# 6           7           4.6          3.4           1.4          0.3  setosa

# %%
# Show DataFrame info for more details about data types and missing values
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Unnamed: 0    150 non-null    int64
#  1   Sepal.Length  142 non-null    float64
#  2   Sepal.Width   139 non-null    float64
#  3   Petal.Length  150 non-null    float64
#  4   Petal.Width   150 non-null    float64
#  5   Species       150 non-null    object
# dtypes: float64(4), int64(1), object(1)
# memory usage: 7.2+ KB

# %%
# You can look at the documentation, but generally, I recommend Googling.
# For example: https://pandas.pydata.org/docs/

# %%
# You can provide the column headers if not already present in the dataset and pass it into the read_csv as shown
# column_headers = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width', 'Species']
# dataset = pd.read_csv(file_path, names=column_headers)

# %%
#Print the dimensions
#dimension = rows x columns
print('Shape:', df.shape)
# Out:
# Shape: (150, 6)

# %%
# Print the header again
print(df.columns)
# Out:
# Index(['Unnamed: 0', 'Sepal.Length', 'Sepal.Width', 'Petal.Length',
#        'Petal.Width', 'Species'],
#       dtype='object')

# %%
# Show the data types of each column
print(df.dtypes)
# Out:
# Unnamed: 0        int64
# Sepal.Length    float64
# Sepal.Width     float64
# Petal.Length    float64
# Petal.Width     float64
# Species          object
# dtype: object

# %%
# Show a summary of the DataFrame using describe()
print(df.describe())
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    142.000000   139.000000    150.000000   150.000000
# mean    75.500000      5.840141     3.043165      3.758000     1.199333
# std     43.445368      0.831905     0.438550      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %% [markdown]
# # [Objective 02](#basic-pandas-functions) - Use basic Pandas functions for Exploratory Data Analysis (EDA)

# %% [markdown]
# ![Workflow.png](data:image/png;base64,...)

# %% [markdown]
# ## Overview
#
# > Exploratory Data Analysis (EDA) refers to the critical process of performing initial investigations on data so as to discover patterns, to spot anomalies, to test hypotheses and to check assumptions with the help of summary statistics and graphical representations
#
# Exploratory Data Analysis is often the first thing that we'll do when starting out with a new dataset.

# %%
#Learn more about the variables in the dataset using info function

# %% [markdown]
# #Learn more about each variable

# %%
#Determine the data types

# %%
# Summary Statistics - using (describe function)
# check if there are non-numeric column

# %% [markdown]
# What is the problem here?

# %% [markdown]
# ????

# %%
# try to exclude non numeric value
print(df.describe(exclude=[object]))
# Out:
#        Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count  150.000000    142.000000   139.000000    150.000000   150.000000
# mean    75.500000      5.840141     3.043165      3.758000     1.199333
# std     43.445368      0.831905     0.438550      1.765298     0.762238
# min      1.000000      4.300000     2.000000      1.000000     0.100000
# 25%     38.250000      5.100000     2.800000      1.600000     0.300000
# 50%     75.500000      5.800000     3.000000      4.350000     1.300000
# 75%    112.750000      6.400000     3.300000      5.100000     1.800000
# max    150.000000      7.900000     4.400000      6.900000     2.500000

# %%
# include all
print(df.describe(include='all'))
# Out:
#         Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# count   150.000000    142.000000   139.000000    150.000000   150.000000
# unique         NaN           NaN          NaN           NaN          NaN
# top            NaN           NaN          NaN           NaN          NaN
# freq           NaN           NaN          NaN           NaN          NaN
# mean     75.500000      5.840141     3.043165      3.758000     1.199333
# std      43.445368      0.831905     0.438550      1.765298     0.762238
# min       1.000000      4.300000     2.000000      1.000000     0.100000
# 25%      38.250000      5.100000     2.800000      1.600000     0.300000
# 50%      75.500000      5.800000     3.000000      4.350000     1.300000
# 75%     112.750000      6.400000     3.300000      5.100000     1.800000
# max     150.000000      7.900000     4.400000      6.900000     2.500000
#
#           Species
# count         150
# unique          8
# top     virginica
# freq           49
# mean          NaN
# std           NaN
# min           NaN
# 25%           NaN
# 50%           NaN
# 75%           NaN
# max           NaN

# %%
# accesss a specific column of the dataframe
print(df['Species'].head())
# Out:
# 0    Setosa
# 1    setosa
# 2    setosa
# 3    setosa
# 4    setosa
# Name: Species, dtype: object

# %%
# Show value counts for the 'Species' column
print(df['Species'].value_counts())
# Out:
# Species
# virginica     49
# setosa        48
# versicolor    48
# Setosa         1
# SETOSA         1
# Versicolor     1
# VERSICOLOR     1
# VIRGINICA      1
# Name: count, dtype: int64

# %%
#sort by values (any specific column)
print(df.sort_values(by='Sepal.Length').head())
# Out:
#     Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 13          14           4.3          3.0           1.1          0.1  setosa
# 42          43           4.4          3.2           1.3          0.2  setosa
# 38          39           4.4          3.0           1.3          0.2  setosa
# 8            9           4.4          2.9           1.4          0.2  setosa
# 41          42           4.5          2.3           1.3          0.3  setosa

# %%
# Sort by Sepal.Width
print(df.sort_values(by='Sepal.Width').head())
# Out:
#      Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width  \
# 60           61           5.0          2.0           3.5          1.0
# 62           63           6.0          2.2           4.0          1.0
# 119         120           6.0          2.2           5.0          1.5
# 68           69           6.2          2.2           4.5          1.5
# 93           94           5.0          2.3           3.3          1.0
#
#         Species
# 60   versicolor
# 62   versicolor
# 119   virginica
# 68   versicolor
# 93   versicolor

# %%
# Show unique values in the Species column
print(df['Species'].unique())
# Out:
# ['Setosa' 'setosa' 'SETOSA' 'versicolor' 'Versicolor' 'VERSICOLOR'
#  'virginica' 'VIRGINICA']

# %%
# check for missing values
# the number of missing values in each column
print(df.isnull().sum())
# Out:
# Unnamed: 0       0
# Sepal.Length     8
# Sepal.Width     11
# Petal.Length     0
# Petal.Width      0
# Species          0
# dtype: int64

# %%
# Total number of missing cells in the entire dataset
print(df.isnull().sum().sum())
# Out:
# 19

# %%
# df.head()
print(df.head())
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 4           5           NaN          3.6           1.4          0.2  setosa

# %%
# try dropping rows from the dataset inplace
df.dropna(inplace=True)
print('After dropping missing values, shape:', df.shape)
# Out:
# After dropping missing values, shape: (131, 6)

# %%
# Show the first 5 rows after dropping missing values
print(df.head())
# Out:
#    Unnamed: 0  Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           1           5.1          3.5           1.4          0.2  Setosa
# 1           2           4.9          3.0           1.4          0.2  setosa
# 2           3           4.7          3.2           1.3          0.2  setosa
# 3           4           4.6          3.1           1.5          0.2  setosa
# 6           7           4.6          3.4           1.4          0.3  setosa

# %%
# Show the number of unique values in each column after cleaning
print(df.nunique())
# Out:
# Unnamed: 0      131
# Sepal.Length     35
# Sepal.Width      23
# Petal.Length     43
# Petal.Width      22
# Species           8
# dtype: int64

# %%
# axis=1 to look through column headers and not row index
#Drop ID variable
#inplace
#drop(column_name, axis=1, inplace=True)# Columns gets removed
df.drop('Unnamed: 0', axis=1, inplace=True)
print(df.head())
# Out:
#    Sepal.Length  Sepal.Width  Petal.Length  Petal.Width Species
# 0           5.1          3.5           1.4          0.2  Setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 6           4.6          3.4           1.4          0.3  setosa

# %% [markdown]
# Recap - what do each of these things do???
#
#
# - df.shape
# - df.head()
# - df.dtypes
# - df.describe()
#  - Numeric
#  - Non-Numeric
# - df['column'].value_counts()
# - df.isnull().sum()
# - df.isnull().sum().sum()
# - df.drop()

# %% [markdown]
# # [Objective 03](#pandas-visualizations) Describe and discriminate between basic data types

# %% [markdown]
# ## Overview
#
# One of the cornerstones of Exploratory Data Analysis (EDA) is being able to identify variable types.  We will need different statistical methods to display and describe each of these different types of data.

# %%
# Load the dataset (ensure df is defined)
import pandas as pd
df = pd.read_csv('iris_dirty (1).csv')

# %%
# Import visualization libraries
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# Categorical (Nominal): Species value counts and bar plot
species_counts = df['Species'].value_counts()
print('Species value counts:')
print(species_counts)
species_counts.plot(kind='bar', figsize=(6,4), color='skyblue')
plt.title('Frequency of Each Species')
plt.xlabel('Species')
plt.ylabel('Count')
plt.show()
# Out:
# Species value counts:
# Species
# virginica     49
# setosa        48
# versicolor    48
# Setosa         1
# SETOSA         1
# Versicolor     1
# VERSICOLOR     1
# VIRGINICA      1
# Name: count, dtype: int64

# %%
# Quantitative (Continuous): Statistical summary for numerical features
num_cols = ['Sepal.Length', 'Sepal.Width', 'Petal.Length', 'Petal.Width']
print('Statistical summary for numerical features:')
print(df[num_cols].describe())
# Out:
# Statistical summary for numerical features:
#        Sepal.Length  Sepal.Width  Petal.Length  Petal.Width
# count    142.000000   139.000000    150.000000   150.000000
# mean       5.840141     3.043165      3.758000     1.199333
# std        0.831905     0.438550      1.765298     0.762238
# min        4.300000     2.000000      1.000000     0.100000
# 25%        5.100000     2.800000      1.600000     0.300000
# 50%        5.800000     3.000000      4.350000     1.300000
# 75%        6.400000     3.300000      5.100000     1.800000
# max        7.900000     4.400000      6.900000     2.500000

# %%
# Boxplots for each numerical feature by Species
for col in num_cols:
    plt.figure(figsize=(7,4))
    sns.boxplot(x='Species', y=col, data=df, palette='Set2')
    plt.title(f'Boxplot of {col} by Species')
    plt.show()
# Out:
# /var/folders/gt/375txlf13c9gt55s5yzgl63m0000gn/T/ipykernel_6757/4038763800.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=col, data=df, palette='Set2')
# /var/folders/gt/375txlf13c9gt55s5yzgl63m0000gn/T/ipykernel_6757/4038763800.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=col, data=df, palette='Set2')
# /var/folders/gt/375txlf13c9gt55s5yzgl63m0000gn/T/ipykernel_6757/4038763800.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=col, data=df, palette='Set2')
# /var/folders/gt/375txlf13c9gt55s5yzgl63m0000gn/T/ipykernel_6757/4038763800.py:4: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.boxplot(x='Species', y=col, data=df, palette='Set2')

# %%
# Pairplot to visualize relationships between numerical features, colored by Species
sns.pairplot(df, hue='Species', diag_kind='hist', palette='Set1')
plt.show()

# %%
# Correlation heatmap for numerical features
corr = df[num_cols].corr()
plt.figure(figsize=(6,5))
sns.heatmap(corr, annot=True, cmap='coolwarm', fmt='.2f')
plt.title('Correlation Heatmap of Numerical Features')
plt.show()
